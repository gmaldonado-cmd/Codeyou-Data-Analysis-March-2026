# %%
print ("Yes it works")
# Out:
# Yes it works

# %%
print ("Hola I Guillermo Maldonado, You can call me G. I like this class, I happy to learn more about data analysis, I am looking forward to learning more")
# Out:
# Hola I Guillermo Maldonado, You can call me G. I like this class, I happy to learn more about data analysis, I am looking forward to learning more
